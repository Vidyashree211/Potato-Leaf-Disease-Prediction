# %%
from keras.models import Sequential
from keras.layers import Conv2D,Flatten,Dense,MaxPooling2D
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.applications.vgg19 import VGG19
vgg19_model=Sequential()
vgg = VGG19(weights="imagenet", include_top=False, input_shape=(256,256,3))
vgg.trainable = False
vgg19_model.add(vgg)
vgg19_model.add(Flatten())
vgg19_model.add(Dense(512, activation='relu'))
vgg19_model.add(Dense(3, activation='softmax'))

vgg19_model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# Summary of the model
vgg19_model.summary()

# Data augmentation and normalization
train_datagen = ImageDataGenerator(rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    brightness_range=[0.5, 1.3],
    fill_mode='nearest')
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Load the training, validation, and test datasets
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/potato_leaf_disease_classification/Train', target_size=(256, 256), batch_size=16, class_mode='categorical',color_mode="rgb")
validation_set = val_datagen.flow_from_directory('/content/drive/MyDrive/potato_leaf_disease_classification/Validation', target_size=(256, 256), batch_size=16, class_mode='categorical',color_mode="rgb")
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/potato_leaf_disease_classification/Test', target_size=(256, 256), batch_size=16, class_mode='categorical',color_mode="rgb")

# Train the model
history = vgg19_model.fit(training_set, steps_per_epoch=20, epochs=50, validation_data=validation_set, validation_steps=20)

# Evaluate the model
test_loss, test_acc = vgg19_model.evaluate(test_set, verbose=2)
print("\n\n")
print("Test Loss: \t", test_loss, "\n")
print("Test Accuracy: \t", test_acc, "\n")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 8, 8, 512)         20024384
#
#  flatten_3 (Flatten)         (None, 32768)             0
#
#  dense_6 (Dense)             (None, 512)               16777728
#
#  dense_7 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 36803651 (140.39 MB)
# Trainable params: 16779267 (64.01 MB)
# Non-trainable params: 20024384 (76.39 MB)
# _________________________________________________________________
# Found 1296 images belonging to 3 classes.
# Found 430 images belonging to 3 classes.
# Found 430 images belonging to 3 classes.
# Epoch 1/50
# 20/20 [==============================] - 11s 467ms/step - loss: 6.1934 - accuracy: 0.5312 - val_loss: 1.2457 - val_accuracy: 0.5750
# Epoch 2/50
# 20/20 [==============================] - 11s 542ms/step - loss: 0.7142 - accuracy: 0.7594 - val_loss: 0.6740 - val_accuracy: 0.7844
# Epoch 3/50
# 20/20 [==============================] - 10s 520ms/step - loss: 0.7510 - accuracy: 0.7437 - val_loss: 0.4740 - val_accuracy: 0.8687
# Epoch 4/50
# 20/20 [==============================] - 10s 500ms/step - loss: 0.6540 - accuracy: 0.8000 - val_loss: 0.3246 - val_accuracy: 0.8781
# Epoch 5/50
# 20/20 [==============================] - 11s 541ms/step - loss: 0.5995 - accuracy: 0.8281 - val_loss: 0.4559 - val_accuracy: 0.8313
# Epoch 6/50
# 20/20 [==============================] - 10s 523ms/step - loss: 0.5325 - accuracy: 0.7812 - val_loss: 0.3266 - val_accuracy: 0.8687
# Epoch 7/50
# 20/20 [==============================] - 11s 550ms/step - loss: 0.5924 - accuracy: 0.7750 - val_loss: 0.5719 - val_accuracy: 0.8094
# Epoch 8/50
# 20/20 [==============================] - 10s 484ms/step - loss: 0.6491 - accuracy: 0.7906 - val_loss: 2.0023 - val_accuracy: 0.5562
# Epoch 9/50
# 20/20 [==============================] - 9s 476ms/step - loss: 0.8392 - accuracy: 0.7656 - val_loss: 0.3810 - val_accuracy: 0.8844
# Epoch 10/50
# 20/20 [==============================] - 10s 516ms/step - loss: 0.5264 - accuracy: 0.8344 - val_loss: 0.3467 - val_accuracy: 0.8594
# Epoch 11/50
# 20/20 [==============================] - 10s 530ms/step - loss: 0.3867 - accuracy: 0.8500 - val_loss: 0.2571 - val_accuracy: 0.8875
# Epoch 12/50
# 20/20 [==============================] - 10s 495ms/step - loss: 0.3062 - accuracy: 0.8781 - val_loss: 0.2186 - val_accuracy: 0.9187
# Epoch 13/50
# 20/20 [==============================] - 9s 469ms/step - loss: 0.2924 - accuracy: 0.8906 - val_loss: 0.2672 - val_accuracy: 0.8969
# Epoch 14/50
# 20/20 [==============================] - 10s 514ms/step - loss: 0.3187 - accuracy: 0.9062 - val_loss: 0.3055 - val_accuracy: 0.8906
# Epoch 15/50
# 20/20 [==============================] - 10s 518ms/step - loss: 0.2775 - accuracy: 0.9000 - val_loss: 0.2091 - val_accuracy: 0.9281
# Epoch 16/50
# 20/20 [==============================] - 9s 473ms/step - loss: 0.2783 - accuracy: 0.8906 - val_loss: 0.3900 - val_accuracy: 0.9125
# Epoch 17/50
# 20/20 [==============================] - 10s 477ms/step - loss: 0.4066 - accuracy: 0.8687 - val_loss: 0.5018 - val_accuracy: 0.8156
# Epoch 18/50
# 20/20 [==============================] - 10s 524ms/step - loss: 0.5348 - accuracy: 0.8219 - val_loss: 0.1813 - val_accuracy: 0.9344
# Epoch 19/50
# 20/20 [==============================] - 10s 500ms/step - loss: 0.4161 - accuracy: 0.8562 - val_loss: 0.3185 - val_accuracy: 0.8750
# Epoch 20/50
# 20/20 [==============================] - 9s 477ms/step - loss: 0.7846 - accuracy: 0.7656 - val_loss: 0.2264 - val_accuracy: 0.9062
# Epoch 21/50
# 20/20 [==============================] - 10s 514ms/step - loss: 0.2653 - accuracy: 0.9031 - val_loss: 0.1724 - val_accuracy: 0.9375
# Epoch 22/50
# 20/20 [==============================] - 10s 530ms/step - loss: 0.2047 - accuracy: 0.9156 - val_loss: 0.1884 - val_accuracy: 0.9281
# Epoch 23/50
# 20/20 [==============================] - 10s 513ms/step - loss: 0.2322 - accuracy: 0.9062 - val_loss: 0.1616 - val_accuracy: 0.9312
# Epoch 24/50
# 20/20 [==============================] - 9s 475ms/step - loss: 0.2869 - accuracy: 0.9125 - val_loss: 0.3145 - val_accuracy: 0.8875
# Epoch 25/50
# 20/20 [==============================] - 10s 495ms/step - loss: 0.2492 - accuracy: 0.9156 - val_loss: 0.2013 - val_accuracy: 0.9250
# Epoch 26/50
# 20/20 [==============================] - 10s 517ms/step - loss: 0.2346 - accuracy: 0.9125 - val_loss: 0.2589 - val_accuracy: 0.8906
# Epoch 27/50
# 20/20 [==============================] - 10s 516ms/step - loss: 0.2636 - accuracy: 0.9156 - val_loss: 0.1990 - val_accuracy: 0.9250
# Epoch 28/50
# 20/20 [==============================] - 9s 453ms/step - loss: 0.2172 - accuracy: 0.9281 - val_loss: 0.1549 - val_accuracy: 0.9375
# Epoch 29/50
# 20/20 [==============================] - 9s 466ms/step - loss: 0.1772 - accuracy: 0.9250 - val_loss: 0.1623 - val_accuracy: 0.9469
# Epoch 30/50
# 20/20 [==============================] - 11s 535ms/step - loss: 0.1682 - accuracy: 0.9344 - val_loss: 0.2263 - val_accuracy: 0.9000
# Epoch 31/50
# 20/20 [==============================] - 10s 512ms/step - loss: 0.3347 - accuracy: 0.8781 - val_loss: 0.2916 - val_accuracy: 0.8969
# Epoch 32/50
# 20/20 [==============================] - 9s 450ms/step - loss: 0.3013 - accuracy: 0.8969 - val_loss: 0.2969 - val_accuracy: 0.8969
# Epoch 33/50
# 20/20 [==============================] - 11s 533ms/step - loss: 0.4445 - accuracy: 0.8281 - val_loss: 0.2787 - val_accuracy: 0.9000
# Epoch 34/50
# 20/20 [==============================] - 10s 520ms/step - loss: 0.2588 - accuracy: 0.8938 - val_loss: 0.2088 - val_accuracy: 0.9031
# Epoch 35/50
# 20/20 [==============================] - 10s 489ms/step - loss: 0.2002 - accuracy: 0.9250 - val_loss: 0.2332 - val_accuracy: 0.9125
# Epoch 36/50
# 20/20 [==============================] - 9s 450ms/step - loss: 0.2343 - accuracy: 0.9031 - val_loss: 0.2406 - val_accuracy: 0.8938
# Epoch 37/50
# 20/20 [==============================] - 10s 512ms/step - loss: 0.2773 - accuracy: 0.8844 - val_loss: 0.2180 - val_accuracy: 0.9156
# Epoch 38/50
# 20/20 [==============================] - 10s 514ms/step - loss: 0.2454 - accuracy: 0.9125 - val_loss: 0.3476 - val_accuracy: 0.8562
# Epoch 39/50
# 20/20 [==============================] - 9s 470ms/step - loss: 0.2434 - accuracy: 0.9000 - val_loss: 0.2011 - val_accuracy: 0.9187
# Epoch 40/50
# 20/20 [==============================] - 9s 455ms/step - loss: 0.2186 - accuracy: 0.8969 - val_loss: 0.2332 - val_accuracy: 0.8906
# Epoch 41/50
# 20/20 [==============================] - 11s 536ms/step - loss: 0.1933 - accuracy: 0.9219 - val_loss: 0.1840 - val_accuracy: 0.9344
# Epoch 42/50
# 20/20 [==============================] - 10s 515ms/step - loss: 0.1955 - accuracy: 0.9312 - val_loss: 0.2019 - val_accuracy: 0.9312
# Epoch 43/50
# 20/20 [==============================] - 9s 476ms/step - loss: 0.1981 - accuracy: 0.9125 - val_loss: 0.3234 - val_accuracy: 0.8656
# Epoch 44/50
# 20/20 [==============================] - 10s 482ms/step - loss: 0.2840 - accuracy: 0.8750 - val_loss: 0.2352 - val_accuracy: 0.9094
# Epoch 45/50
# 20/20 [==============================] - 10s 512ms/step - loss: 0.1965 - accuracy: 0.9219 - val_loss: 0.2657 - val_accuracy: 0.9031
# Epoch 46/50
# 20/20 [==============================] - 10s 511ms/step - loss: 0.2410 - accuracy: 0.8906 - val_loss: 0.2227 - val_accuracy: 0.9156
# Epoch 47/50
# 20/20 [==============================] - 12s 608ms/step - loss: 0.2600 - accuracy: 0.9000 - val_loss: 0.2555 - val_accuracy: 0.9187
# Epoch 48/50
# 20/20 [==============================] - 10s 506ms/step - loss: 0.2414 - accuracy: 0.9000 - val_loss: 0.1539 - val_accuracy: 0.9281
# Epoch 49/50
# 20/20 [==============================] - 11s 535ms/step - loss: 0.2482 - accuracy: 0.8906 - val_loss: 0.1797 - val_accuracy: 0.9312
# Epoch 50/50
# 20/20 [==============================] - 10s 510ms/step - loss: 0.2585 - accuracy: 0.9062 - val_loss: 0.1908 - val_accuracy: 0.9281
# 27/27 - 3s - loss: 0.2068 - accuracy: 0.9256 - 3s/epoch - 112ms/step
#
#
#
# Test Loss: 	 0.2067592740058899
#
# Test Accuracy: 	 0.9255813956260681

# %%
vgg19_model.save('final_model5.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from matplotlib import pyplot as plt
EPOCHS = 50
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np
from keras.preprocessing import image
import keras.utils as image

# Load and preprocess the test image
test_image = image.load_img('/content/drive/MyDrive/Potato_Healthy.jpg', target_size=(256, 256))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)

# Predict the class of the test image
result = vgg19_model.predict(test_image)
print(result)

# Assuming the class indices mapping
# training_set.class_indices will return a dictionary like {'class1': 0, 'class2': 1, 'class3': 2}
class_indices = training_set.class_indices
class_labels = {v: k for k, v in class_indices.items()}  # Reverse the dictionary to get labels from indices

# Get the predicted class index
predicted_class_index = np.argmax(result, axis=1)[0]
prediction = class_labels[predicted_class_index]

print(prediction)
# Out:
# 1/1 [==============================] - 0s 150ms/step
# [[7.427830e-30 2.467466e-09 1.000000e+00]]
# Potato___healthy

# %%
import numpy as np
from keras.preprocessing import image
import keras.utils as image

# Load and preprocess the test image
test_image = image.load_img('/content/drive/MyDrive/test_potato_early_blight.jpg', target_size=(256, 256))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)

# Predict the class of the test image
result = vgg19_model.predict(test_image)
print(result)

# Assuming the class indices mapping
# training_set.class_indices will return a dictionary like {'class1': 0, 'class2': 1, 'class3': 2}
class_indices = training_set.class_indices
class_labels = {v: k for k, v in class_indices.items()}  # Reverse the dictionary to get labels from indices

# Get the predicted class index
predicted_class_index = np.argmax(result, axis=1)[0]
prediction = class_labels[predicted_class_index]

print(prediction)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# [[1. 0. 0.]]
# Potato___Early_blight
